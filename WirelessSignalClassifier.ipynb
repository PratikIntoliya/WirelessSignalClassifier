# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score

# Generate some sample data (replace this with your actual dataset)
np.random.seed(0)
num_samples = 1000
signal_strength = np.random.rand(num_samples, 1)  # Random signal strength data
signal_type = np.random.choice(['WiFi', 'Bluetooth', 'LTE'], num_samples)  # Random signal type data

# Encode the signal type labels
label_encoder = LabelEncoder()
signal_type_encoded = label_encoder.fit_transform(signal_type)

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(signal_strength, signal_type_encoded, test_size=0.2, random_state=0)

# Normalize the input features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build a simple neural network model
model = keras.Sequential([
    keras.layers.Dense(64, activation='relu', input_shape=(1,)),
    keras.layers.Dense(3, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Train the model
model.fit(X_train_scaled, y_train, epochs=50, batch_size=32, validation_data=(X_test_scaled, y_test))

# Evaluate the model
loss, accuracy = model.evaluate(X_test_scaled, y_test)
print(f"Test Loss: {loss}")
print(f"Test Accuracy: {accuracy}")

# Use the model to make predictions
y_pred = np.argmax(model.predict(X_test_scaled), axis=-1)
print(f"Accuracy Score: {accuracy_score(y_test, y_pred)}")
# Out:
# Epoch 1/50
# 25/25 [==============================] - 0s 3ms/step - loss: 1.1088 - accuracy: 0.3175 - val_loss: 1.1037 - val_accuracy: 0.2950
# Epoch 2/50
#  1/25 [>.............................] - ETA: 0s - loss: 1.1021 - accuracy: 0.2812
# 2024-03-30 19:01:14.543502: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 25/25 [==============================] - 0s 895us/step - loss: 1.1014 - accuracy: 0.3025 - val_loss: 1.0986 - val_accuracy: 0.3450
# Epoch 3/50
# 25/25 [==============================] - 0s 905us/step - loss: 1.0991 - accuracy: 0.3237 - val_loss: 1.0988 - val_accuracy: 0.3450
# Epoch 4/50
# 25/25 [==============================] - 0s 924us/step - loss: 1.0989 - accuracy: 0.3413 - val_loss: 1.0983 - val_accuracy: 0.3500
# Epoch 5/50
# 25/25 [==============================] - 0s 901us/step - loss: 1.0982 - accuracy: 0.3600 - val_loss: 1.0992 - val_accuracy: 0.3500
# Epoch 6/50
# ...
